# %%
import pandas as pd
import numpy as np
import string

import nltk
from nltk.stem import PorterStemmer

# %%
# Set global parameters
N_TOPICS = 10
LANGUAGE = "english"
SENTENCES_COUNT = 2
try:
    from nltk.corpus import stopwords
    STOP_WORDS = set(stopwords.words(LANGUAGE))
except:
    nltk.download('stopwords')
STOP_WORDS = set(stopwords.words(LANGUAGE))

PUNCTUATIONS = set(string.punctuation)

# %%
def _clean(document):
    # Tokenize
    words = nltk.word_tokenize(document)

    # Remove abstraction
    clean_document = [word.lower() for word in words if word.lower() not in STOP_WORDS]
    clean_document = [word for word in clean_document if word not in PUNCTUATIONS]

    # Stem
    stemmer = PorterStemmer()
    clean_document = " ".join([stemmer.stem(word) for word in clean_document])
    return clean_document

# %%
def _get_topics(document):
    #document = document.split()
    #if len(document) >= 2:
    #    n_features = len(document)
    #else:
    #    n_features = 1

    ## Fit tfidf vectorizer
    #tf_vec = TfidfVectorizer(max_features=n_features, stop_words='english').fit(document)

    ## Convert document to tfidf
    #tf = tf_vec.transform(document)

    ## Get feature names
    #feature_names = tf_vec.get_feature_names()

    ## Fit NMF topic model
    #model = NMF(alpha=0.1, l1_ratio=0.75).fit(tf)

    ## Output topics
    #topics = []
    #for topic_idx, topic in enumerate(model.components_):
    #    for i in topic.argsort()[:-N_TOPICS - 1:-1]:
    #        topics.append(feature_names[i])
    #return " ".join(np.unique(topics))

    document = _filter(document)
    parser = PlaintextParser.from_string(document.lower(), Tokenizer(LANGUAGE))
    summarizer = Summarizer()
    summarizer.stop_words = STOP_WORDS

    summary = " "
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        summary += " ".join(sentence.words) + "."
    return summary

# %%
bailey = open('bailey.txt','r')
#print(bailey.read())
bailey_string = bailey.read()
tokens = nltk.word_tokenize(bailey_string)
tokens
# Out:
# ['Betty',
#  'Lou',
#  'Bailey',
#  '(',
#  '1929',
#  '–',
#  '2007',
#  ')',
#  '[',
#  '1',
#  ']',
#  'was',
#  'a',
#  'General',
#  'Electric',
#  'Company',
#  'mechanical',
#  'engineer',
#  'from',
#  'the',
#  'United',
#  'States',
#  '.',
#  'She',
#  'held',
#  'a',
#  'patent',
#  'for',
#  'the',
#  'converging',
#  'diverging',
#  'variable',
#  'exhaust',
#  'nozzle',
#  '.',
#  'The',
#  'invention',
#  'operated',
#  'so',
#  'that',
#  'one',
#  'would',
#  'vary',
#  'both',
#  'the',
#  'throat',
#  'and',
#  'the',
#  'exit',
#  'diameters',
#  'for',
#  'the',
#  'hot',
#  'gas',
#  'flows',
#  '.',
#  '[',
#  '2',
#  ']',
#  'In',
#  'honor',
#  'of',
#  'her',
#  'legacy',
#  ',',
#  'the',
#  'Society',
#  'of',
#  'Women',
#  'Engineers',
#  'named',
#  'a',
#  'scholarship',
#  'after',
#  'her',
#  '.',
#  'To',
#  'date',
#  ',',
#  'that',
#  'scholarship',
#  'is',
#  'still',
#  'being',
#  'distributed',
#  'to',
#  'eligible',
#  'female',
#  'graduate',
#  'students',
#  'who',
#  'pursue',
#  'a',
#  'career',
#  'in',
#  'engineering',
#  '.',
#  '[',
#  '3',
#  ']',
#  'Bailey',
#  'was',
#  'the',
#  'first',
#  'female',
#  'member',
#  'of',
#  'the',
#  'Engineering',
#  'Society',
#  'of',
#  'Cincinnati',
#  '.',
#  'She',
#  'later',
#  'served',
#  'as',
#  'the',
#  'chair',
#  'of',
#  'its',
#  'Guidance',
#  'Committee',
#  '.',
#  'Bailey',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'five',
#  'children',
#  '.',
#  'She',
#  'excelled',
#  'in',
#  'math',
#  'and',
#  'science',
#  'in',
#  'high',
#  'school',
#  '.',
#  'Although',
#  'her',
#  'father',
#  'was',
#  'a',
#  'civil',
#  'engineer',
#  ',',
#  'it',
#  'was',
#  'her',
#  'oldest',
#  'sister',
#  'Helen',
#  'and',
#  'her',
#  'husband',
#  'Paul',
#  'who',
#  'influenced',
#  'Bailey',
#  'to',
#  'choose',
#  'a',
#  'career',
#  'in',
#  'engineering',
#  '.',
#  'Paul',
#  'sold',
#  'welding',
#  'machines',
#  'and',
#  'taught',
#  'Helen',
#  'to',
#  'weld',
#  '.',
#  'Helen',
#  'taught',
#  'welding',
#  'to',
#  'various',
#  'men',
#  'and',
#  'women',
#  'during',
#  'World',
#  'War',
#  'II',
#  '.',
#  'Although',
#  'a',
#  'number',
#  'of',
#  'Helen',
#  "'s",
#  'female',
#  'welding',
#  'students',
#  'scored',
#  'higher',
#  'than',
#  'the',
#  'male',
#  'students',
#  ',',
#  'all',
#  'of',
#  'the',
#  'men',
#  'were',
#  'placed',
#  'first',
#  'before',
#  'the',
#  'women',
#  ',',
#  'regardless',
#  'of',
#  'the',
#  'score',
#  '.',
#  'So',
#  ',',
#  'between',
#  'Betty',
#  'Lou',
#  'Bailey',
#  "'s",
#  'junior',
#  'and',
#  'senior',
#  'years',
#  'in',
#  'high',
#  'school',
#  ',',
#  'Helen',
#  'suggested',
#  'that',
#  'Betty',
#  'Lou',
#  'should',
#  'go',
#  'into',
#  'engineering',
#  '.',
#  '[',
#  '4',
#  ']',
#  'Education',
#  'Bailey',
#  'attended',
#  'the',
#  'undergraduate',
#  'program',
#  'in',
#  'mechanical',
#  'engineering',
#  'at',
#  'the',
#  'University',
#  'of',
#  'Illinois',
#  'a',
#  'year',
#  'early',
#  ',',
#  'at',
#  'the',
#  'age',
#  'of',
#  'seventeen',
#  '.',
#  'By',
#  'the',
#  'time',
#  'she',
#  'finished',
#  'her',
#  'freshman',
#  'year',
#  ',',
#  'both',
#  'of',
#  'Bailey',
#  "'s",
#  'parents',
#  'had',
#  'died',
#  '.',
#  'In',
#  '1950',
#  ',',
#  'Bailey',
#  'graduated',
#  'with',
#  'University',
#  'Honors',
#  '.',
#  'In',
#  'her',
#  'graduating',
#  'class',
#  'of',
#  'approximately',
#  '700',
#  'engineers',
#  ',',
#  'she',
#  'was',
#  'the',
#  'only',
#  'female',
#  'engineer',
#  '.',
#  '[',
#  '2',
#  ']',
#  'In',
#  'her',
#  'sorority',
#  ',',
#  'she',
#  'was',
#  'one',
#  'out',
#  'of',
#  'a',
#  'total',
#  'of',
#  'two',
#  'engineers',
#  '(',
#  'the',
#  'other',
#  'one',
#  'was',
#  'a',
#  'civil',
#  'engineer',
#  ')',
#  '.',
#  '[',
#  '2',
#  ']',
#  'In',
#  '1967',
#  ',',
#  'she',
#  'graduated',
#  'from',
#  'the',
#  'Penn',
#  'State',
#  'Graduate',
#  'Center',
#  'in',
#  'King',
#  'of',
#  'Prussia',
#  'with',
#  'a',
#  'Masters',
#  'in',
#  'the',
#  'Engineering',
#  'Science',
#  '.',
#  '[',
#  '1',
#  ']',
#  'Personal',
#  'Life',
#  'and',
#  'Death',
#  'Bailey',
#  'was',
#  'an',
#  'active',
#  'environmentalist',
#  '.',
#  'She',
#  'enjoyed',
#  'sewing',
#  '.',
#  'She',
#  'traveled',
#  ',',
#  'canoed',
#  ',',
#  'cycled',
#  ',',
#  'and',
#  'hiked',
#  '.',
#  'She',
#  'walked',
#  'the',
#  'entire',
#  'Appalachian',
#  'Trail',
#  'in',
#  'segments',
#  'over',
#  'a',
#  'few',
#  'years',
#  '.',
#  'She',
#  'was',
#  'a',
#  'member',
#  'of',
#  'the',
#  'Adirondack',
#  'Mountain',
#  'Club',
#  '(',
#  'ADK',
#  ')',
#  '.',
#  'In',
#  '2004',
#  'she',
#  'received',
#  'their',
#  'highest',
#  'award',
#  'for',
#  'her',
#  'work',
#  'in',
#  'monitoring',
#  'hydropower',
#  'applications',
#  'to',
#  'the',
#  'Federal',
#  'Regulatory',
#  'Commission',
#  '.',
#  'She',
#  'did',
#  'work',
#  'in',
#  'dam-licensing',
#  'that',
#  'helped',
#  'ensure',
#  'that',
#  'sufficient',
#  'water',
#  'was',
#  'released',
#  'downstream',
#  'to',
#  'support',
#  'river',
#  'life',
#  'and',
#  'water',
#  'recreation',
#  '.',
#  '[',
#  '1',
#  ']',
#  'Bailey',
#  'died',
#  'suddenly',
#  'on',
#  'November',
#  '13',
#  ',',
#  '2007',
#  ',',
#  'during',
#  'an',
#  'ADK',
#  'cycling',
#  'trip',
#  '.',
#  '[',
#  '1',
#  ']',
#  'Career',
#  'and',
#  'Contributions',
#  'Bailey',
#  'held',
#  'positions',
#  'at',
#  'General',
#  'Electric',
#  'Company',
#  'as',
#  'a',
#  'testing',
#  ',',
#  'design',
#  ',',
#  'and',
#  'systems',
#  'engineer',
#  'in',
#  'their',
#  'Large',
#  'Jet',
#  'Engine',
#  'Department',
#  ',',
#  'Gas',
#  'Turbine',
#  'Department',
#  ',',
#  'and',
#  'its',
#  'Valley',
#  'Forge',
#  'Space',
#  'Technology',
#  'Center',
#  '.',
#  'She',
#  'progressed',
#  'in',
#  'her',
#  'work',
#  ',',
#  'from',
#  'household',
#  'appliances',
#  ',',
#  'to',
#  'steam',
#  'turbines',
#  'and',
#  'jet',
#  'engineers',
#  ',',
#  'and',
#  'finally',
#  'to',
#  'the',
#  'NASA',
#  'Nimbus',
#  'weather',
#  'satellite',
#  'project',
#  '.',
#  'During',
#  'her',
#  'initial',
#  'job',
#  'interview',
#  'with',
#  'GE',
#  ',',
#  'which',
#  'occurred',
#  'before',
#  'she',
#  'graduated',
#  'from',
#  'the',
#  'University',
#  'of',
#  'Illinois',
#  ',',
#  'she',
#  'remarked',
#  'that',
#  ',',
#  '``',
#  'I',
#  'wanted',
#  'to',
#  'work',
#  'for',
#  'a',
#  'company',
#  'where',
#  'engineers',
#  'counted',
#  'and',
#  'were',
#  'regarded',
#  'as',
#  'important',
#  '.',
#  '``',
#  '[',
#  '2',
#  ']',
#  'In',
#  'addition',
#  'to',
#  'her',
#  'work',
#  ',',
#  'Bailey',
#  'started',
#  'a',
#  'math',
#  'tournament',
#  'in',
#  'Cincinnati',
#  'for',
#  'high',
#  'school',
#  'students',
#  '.',
#  '[',
#  '4',
#  ']',
#  'Exhaust',
#  'Nozzle',
#  'During',
#  'her',
#  'tenure',
#  'at',
#  'General',
#  'Electric',
#  ',',
#  'Bailey',
#  'patented',
#  'an',
#  'exhaust',
#  'nozzle',
#  'in',
#  'Evandale',
#  '.',
#  'She',
#  'initiated',
#  'the',
#  'format',
#  'that',
#  'GE',
#  'used',
#  'for',
#  'getting',
#  'bids',
#  'on',
#  'their',
#  'air',
#  'emission',
#  'tests',
#  '.',
#  '[',
#  '4',
#  ']',
#  'The',
#  'company',
#  'had',
#  'the',
#  '7F',
#  'gas',
#  'turbine',
#  ',',
#  'which',
#  'was',
#  'the',
#  'first-of-its-kind',
#  '.',
#  'She',
#  'was',
#  'working',
#  'at',
#  'the',
#  'roof',
#  'of',
#  'the',
#  'building',
#  'and',
#  'was',
#  'familiar',
#  'with',
#  'enough',
#  'with',
#  'the',
#  'piping',
#  'to',
#  'recognize',
#  'a',
#  'leak',
#  'out',
#  'of',
#  'the',
#  'gas',
#  'line',
#  'from',
#  'the',
#  'gas',
#  'valve',
#  'compartment',
#  '.',
#  'The',
#  'company',
#  'was',
#  'losing',
#  'a',
#  'lot',
#  'of',
#  'gas',
#  'that',
#  'had',
#  'already',
#  'been',
#  'counted',
#  'as',
#  'going',
#  'into',
#  'the',
#  'turbine',
#  '.',
#  'Bailey',
#  'noted',
#  'the',
#  'failed',
#  'efficiency',
#  '.',
#  'That',
#  'gas',
#  'leak',
#  'was',
#  'going',
#  'into',
#  'the',
#  'incoming',
#  'gas',
#  'in',
#  'the',
#  'machine',
#  ',',
#  'so',
#  'the',
#  'carbon',
#  'monoxide',
#  'was',
#  'destroying',
#  'the',
#  'seal',
#  '.',
#  'All',
#  'six',
#  'weeks',
#  'of',
#  'prior',
#  'combustion',
#  'tests',
#  'that',
#  'the',
#  'employees',
#  'had',
#  'been',
#  'running',
#  'on',
#  'the',
#  'machine',
#  'had',
#  'to',
#  'be',
#  'discarded',
#  '.',
#  'Her',
#  'invention',
#  'straightened',
#  'out',
#  'the',
#  'problem',
#  ',',
#  'and',
#  'they',
#  'passed',
#  'the',
#  'tests',
#  'after',
#  'that',
#  '.',
#  'This',
#  'was',
#  'important',
#  'because',
#  'the',
#  'company',
#  "'s",
#  'gas',
#  'turbine',
#  'was',
#  'the',
#  'first',
#  'of',
#  'its',
#  'kind',
#  'and',
#  'would',
#  'therefore',
#  'need',
#  'to',
#  'pass',
#  'all',
#  'of',
#  'its',
#  'tests',
#  '.',
#  '[',
#  '4',
#  ']',
#  'Societies',
#  'In',
#  '1964',
#  ',',
#  'Bailey',
#  'attended',
#  'the',
#  'first',
#  'International',
#  'Conference',
#  'of',
#  'Women',
#  'Engineers',
#  'and',
#  'Scientists',
#  'Conference',
#  'in',
#  'New',
#  'York',
#  '.',
#  '[',
#  '4',
#  ']',
#  'Bailey',
#  'joined',
#  'the',
#  'Society',
#  'of',
#  'Women',
#  'Engineers',
#  'in',
#  '1951',
#  ',',
#  'where',
#  'she',
#  'was',
#  'an',
#  'officer',
#  'of',
#  'the',
#  'Philadelphia',
#  'section',
#  'and',
#  'served',
#  'on',
#  'the',
#  'SWE',
#  'Executive',
#  'Committee',
#  '.',
#  'In',
#  '1985',
#  ',',
#  'she',
#  'was',
#  'elected',
#  'to',
#  'the',
#  'SWE',
#  'College',
#  'of',
#  'Fellows',
#  '.',
#  'She',
#  'was',
#  'the',
#  'first',
#  'female',
#  'member',
#  'of',
#  'the',
#  'Engineering',
#  'Society',
#  'of',
#  'Cincinnati',
#  'and',
#  'served',
#  'as',
#  'the',
#  'chair',
#  'of',
#  'its',
#  'Guidance',
#  'Committee',
#  '.',
#  'She',
#  'has',
#  'also',
#  'served',
#  'on',
#  'national',
#  'committees',
#  'for',
#  'the',
#  'National',
#  'Society',
#  'of',
#  'Professional',
#  'Engineers',
#  ',',
#  'the',
#  'Engineers',
#  'Joint',
#  'Council',
#  ',',
#  'and',
#  'the',
#  'American',
#  'Society',
#  'for',
#  'Engineering',
#  'Education',
#  '.']

# %%
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('Betty', 'NNP'),
#  ('Lou', 'NNP'),
#  ('Bailey', 'NNP'),
#  ('(', '('),
#  ('1929', 'CD'),
#  ('–', 'IN'),
#  ('2007', 'CD'),
#  (')', ')'),
#  ('[', 'VBD'),
#  ('1', 'CD'),
#  (']', 'NN'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('General', 'NNP'),
#  ('Electric', 'NNP'),
#  ('Company', 'NNP'),
#  ('mechanical', 'JJ'),
#  ('engineer', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('held', 'VBD'),
#  ('a', 'DT'),
#  ('patent', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('converging', 'VBG'),
#  ('diverging', 'NN'),
#  ('variable', 'JJ'),
#  ('exhaust', 'JJ'),
#  ('nozzle', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('invention', 'NN'),
#  ('operated', 'VBD'),
#  ('so', 'RB'),
#  ('that', 'IN'),
#  ('one', 'CD'),
#  ('would', 'MD'),
#  ('vary', 'VB'),
#  ('both', 'DT'),
#  ('the', 'DT'),
#  ('throat', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('exit', 'NN'),
#  ('diameters', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('hot', 'JJ'),
#  ('gas', 'NN'),
#  ('flows', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('2', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('honor', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('legacy', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Society', 'NNP'),
#  ('of', 'IN'),
#  ('Women', 'NNP'),
#  ('Engineers', 'NNP'),
#  ('named', 'VBD'),
#  ('a', 'DT'),
#  ('scholarship', 'NN'),
#  ('after', 'IN'),
#  ('her', 'PRP$'),
#  ('.', '.'),
#  ('To', 'TO'),
#  ('date', 'NN'),
#  (',', ','),
#  ('that', 'IN'),
#  ('scholarship', 'NN'),
#  ('is', 'VBZ'),
#  ('still', 'RB'),
#  ('being', 'VBG'),
#  ('distributed', 'VBN'),
#  ('to', 'TO'),
#  ('eligible', 'VB'),
#  ('female', 'JJ'),
#  ('graduate', 'NN'),
#  ('students', 'NNS'),
#  ('who', 'WP'),
#  ('pursue', 'VBP'),
#  ('a', 'DT'),
#  ('career', 'NN'),
#  ('in', 'IN'),
#  ('engineering', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('3', 'CD'),
#  (']', 'JJ'),
#  ('Bailey', 'NNP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('female', 'JJ'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Engineering', 'NNP'),
#  ('Society', 'NNP'),
#  ('of', 'IN'),
#  ('Cincinnati', 'NNP'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('later', 'RB'),
#  ('served', 'VBD'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('chair', 'NN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('Guidance', 'NNP'),
#  ('Committee', 'NNP'),
#  ('.', '.'),
#  ('Bailey', 'NNP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('youngest', 'JJS'),
#  ('of', 'IN'),
#  ('five', 'CD'),
#  ('children', 'NNS'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('excelled', 'VBD'),
#  ('in', 'IN'),
#  ('math', 'NN'),
#  ('and', 'CC'),
#  ('science', 'NN'),
#  ('in', 'IN'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('her', 'PRP$'),
#  ('father', 'NN'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('civil', 'JJ'),
#  ('engineer', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('her', 'PRP'),
#  ('oldest', 'JJS'),
#  ('sister', 'NN'),
#  ('Helen', 'NNP'),
#  ('and', 'CC'),
#  ('her', 'PRP$'),
#  ('husband', 'NN'),
#  ('Paul', 'NNP'),
#  ('who', 'WP'),
#  ('influenced', 'VBD'),
#  ('Bailey', 'NNP'),
#  ('to', 'TO'),
#  ('choose', 'VB'),
#  ('a', 'DT'),
#  ('career', 'NN'),
#  ('in', 'IN'),
#  ('engineering', 'NN'),
#  ('.', '.'),
#  ('Paul', 'NNP'),
#  ('sold', 'VBD'),
#  ('welding', 'VBG'),
#  ('machines', 'NNS'),
#  ('and', 'CC'),
#  ('taught', 'VBD'),
#  ('Helen', 'NNP'),
#  ('to', 'TO'),
#  ('weld', 'VB'),
#  ('.', '.'),
#  ('Helen', 'NNP'),
#  ('taught', 'VBD'),
#  ('welding', 'VBG'),
#  ('to', 'TO'),
#  ('various', 'JJ'),
#  ('men', 'NNS'),
#  ('and', 'CC'),
#  ('women', 'NNS'),
#  ('during', 'IN'),
#  ('World', 'NNP'),
#  ('War', 'NNP'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('a', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('Helen', 'NNP'),
#  ("'s", 'POS'),
#  ('female', 'JJ'),
#  ('welding', 'NN'),
#  ('students', 'NNS'),
#  ('scored', 'VBD'),
#  ('higher', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('male', 'JJ'),
#  ('students', 'NNS'),
#  (',', ','),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('men', 'NNS'),
#  ('were', 'VBD'),
#  ('placed', 'VBN'),
#  ('first', 'RB'),
#  ('before', 'IN'),
#  ('the', 'DT'),
#  ('women', 'NNS'),
#  (',', ','),
#  ('regardless', 'RB'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('score', 'NN'),
#  ('.', '.'),
#  ('So', 'RB'),
#  (',', ','),
#  ('between', 'IN'),
#  ('Betty', 'NNP'),
#  ('Lou', 'NNP'),
#  ('Bailey', 'NNP'),
#  ("'s", 'POS'),
#  ('junior', 'NN'),
#  ('and', 'CC'),
#  ('senior', 'JJ'),
#  ('years', 'NNS'),
#  ('in', 'IN'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  (',', ','),
#  ('Helen', 'NNP'),
#  ('suggested', 'VBD'),
#  ('that', 'IN'),
#  ('Betty', 'NNP'),
#  ('Lou', 'NNP'),
#  ('should', 'MD'),
#  ('go', 'VB'),
#  ('into', 'IN'),
#  ('engineering', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('4', 'CD'),
#  (']', 'JJ'),
#  ('Education', 'NNP'),
#  ('Bailey', 'NNP'),
#  ('attended', 'VBD'),
#  ('the', 'DT'),
#  ('undergraduate', 'JJ'),
#  ('program', 'NN'),
#  ('in', 'IN'),
#  ('mechanical', 'JJ'),
#  ('engineering', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('University', 'NNP'),
#  ('of', 'IN'),
#  ('Illinois', 'NNP'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('early', 'RB'),
#  (',', ','),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('age', 'NN'),
#  ('of', 'IN'),
#  ('seventeen', 'NN'),
#  ('.', '.'),
#  ('By', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('she', 'PRP'),
#  ('finished', 'VBD'),
#  ('her', 'PRP'),
#  ('freshman', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('both', 'DT'),
#  ('of', 'IN'),
#  ('Bailey', 'NNP'),
#  ("'s", 'POS'),
#  ('parents', 'NNS'),
#  ('had', 'VBD'),
#  ('died', 'VBN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('1950', 'CD'),
#  (',', ','),
#  ('Bailey', 'NNP'),
#  ('graduated', 'VBD'),
#  ('with', 'IN'),
#  ('University', 'NNP'),
#  ('Honors', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('her', 'PRP$'),
#  ('graduating', 'JJ'),
#  ('class', 'NN'),
#  ('of', 'IN'),
#  ('approximately', 'RB'),
#  ('700', 'CD'),
#  ('engineers', 'NNS'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('only', 'JJ'),
#  ('female', 'NN'),
#  ('engineer', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('2', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('her', 'PRP$'),
#  ('sorority', 'NN'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('one', 'CD'),
#  ('out', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('total', 'NN'),
#  ('of', 'IN'),
#  ('two', 'CD'),
#  ('engineers', 'NNS'),
#  ('(', '('),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('one', 'NN'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('civil', 'JJ'),
#  ('engineer', 'NN'),
#  (')', ')'),
#  ('.', '.'),
#  ('[', '$'),
#  ('2', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('1967', 'CD'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('graduated', 'VBD'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('Penn', 'NNP'),
#  ('State', 'NNP'),
#  ('Graduate', 'NNP'),
#  ('Center', 'NNP'),
#  ('in', 'IN'),
#  ('King', 'NNP'),
#  ('of', 'IN'),
#  ('Prussia', 'NNP'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('Masters', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Engineering', 'NNP'),
#  ('Science', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('1', 'CD'),
#  (']', 'JJ'),
#  ('Personal', 'NNP'),
#  ('Life', 'NNP'),
#  ('and', 'CC'),
#  ('Death', 'NNP'),
#  ('Bailey', 'NNP'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('active', 'JJ'),
#  ('environmentalist', 'NN'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('enjoyed', 'VBD'),
#  ('sewing', 'VBG'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('traveled', 'VBD'),
#  (',', ','),
#  ('canoed', 'NN'),
#  (',', ','),
#  ('cycled', 'VBN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('hiked', 'VBD'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('walked', 'VBD'),
#  ('the', 'DT'),
#  ('entire', 'JJ'),
#  ('Appalachian', 'JJ'),
#  ('Trail', 'NN'),
#  ('in', 'IN'),
#  ('segments', 'NNS'),
#  ('over', 'IN'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Adirondack', 'NNP'),
#  ('Mountain', 'NNP'),
#  ('Club', 'NNP'),
#  ('(', '('),
#  ('ADK', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2004', 'CD'),
#  ('she', 'PRP'),
#  ('received', 'VBD'),
#  ('their', 'PRP$'),
#  ('highest', 'JJS'),
#  ('award', 'NN'),
#  ('for', 'IN'),
#  ('her', 'PRP$'),
#  ('work', 'NN'),
#  ('in', 'IN'),
#  ('monitoring', 'VBG'),
#  ('hydropower', 'NN'),
#  ('applications', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Federal', 'NNP'),
#  ('Regulatory', 'NNP'),
#  ('Commission', 'NNP'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('did', 'VBD'),
#  ('work', 'NN'),
#  ('in', 'IN'),
#  ('dam-licensing', 'NN'),
#  ('that', 'IN'),
#  ('helped', 'VBD'),
#  ('ensure', 'VB'),
#  ('that', 'DT'),
#  ('sufficient', 'JJ'),
#  ('water', 'NN'),
#  ('was', 'VBD'),
#  ('released', 'VBN'),
#  ('downstream', 'NN'),
#  ('to', 'TO'),
#  ('support', 'VB'),
#  ('river', 'NN'),
#  ('life', 'NN'),
#  ('and', 'CC'),
#  ('water', 'NN'),
#  ('recreation', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('1', 'CD'),
#  (']', 'JJ'),
#  ('Bailey', 'NNP'),
#  ('died', 'VBD'),
#  ('suddenly', 'RB'),
#  ('on', 'IN'),
#  ('November', 'NNP'),
#  ('13', 'CD'),
#  (',', ','),
#  ('2007', 'CD'),
#  (',', ','),
#  ('during', 'IN'),
#  ('an', 'DT'),
#  ('ADK', 'NNP'),
#  ('cycling', 'NN'),
#  ('trip', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('1', 'CD'),
#  (']', 'JJ'),
#  ('Career', 'NNP'),
#  ('and', 'CC'),
#  ('Contributions', 'NNP'),
#  ('Bailey', 'NNP'),
#  ('held', 'VBD'),
#  ('positions', 'NNS'),
#  ('at', 'IN'),
#  ('General', 'NNP'),
#  ('Electric', 'NNP'),
#  ('Company', 'NNP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('testing', 'NN'),
#  (',', ','),
#  ('design', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('systems', 'NNS'),
#  ('engineer', 'VBP'),
#  ('in', 'IN'),
#  ('their', 'PRP$'),
#  ('Large', 'JJ'),
#  ('Jet', 'NNP'),
#  ('Engine', 'NNP'),
#  ('Department', 'NNP'),
#  (',', ','),
#  ('Gas', 'NNP'),
#  ('Turbine', 'NNP'),
#  ('Department', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('Valley', 'NNP'),
#  ('Forge', 'NNP'),
#  ('Space', 'NNP'),
#  ('Technology', 'NNP'),
#  ('Center', 'NNP'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('progressed', 'VBD'),
#  ('in', 'IN'),
#  ('her', 'PRP'),
#  ('work', 'NN'),
#  (',', ','),
#  ('from', 'IN'),
#  ('household', 'NN'),
#  ('appliances', 'NNS'),
#  (',', ','),
#  ('to', 'TO'),
#  ('steam', 'VB'),
#  ('turbines', 'NNS'),
#  ('and', 'CC'),
#  ('jet', 'NN'),
#  ('engineers', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('finally', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('NASA', 'NNP'),
#  ('Nimbus', 'NNP'),
#  ('weather', 'PRP$'),
#  ('satellite', 'NN'),
#  ('project', 'NN'),
#  ('.', '.'),
#  ('During', 'IN'),
#  ('her', 'PRP$'),
#  ('initial', 'JJ'),
#  ('job', 'NN'),
#  ('interview', 'NN'),
#  ('with', 'IN'),
#  ('GE', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('occurred', 'VBD'),
#  ('before', 'IN'),
#  ('she', 'PRP'),
#  ('graduated', 'VBD'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('University', 'NNP'),
#  ('of', 'IN'),
#  ('Illinois', 'NNP'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('remarked', 'VBD'),
#  ('that', 'IN'),
#  (',', ','),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('wanted', 'VBD'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('company', 'NN'),
#  ('where', 'WRB'),
#  ('engineers', 'NNS'),
#  ('counted', 'VBN'),
#  ('and', 'CC'),
#  ('were', 'VBD'),
#  ('regarded', 'VBN'),
#  ('as', 'IN'),
#  ('important', 'JJ'),
#  ('.', '.'),
#  ('``', '``'),
#  ('[', 'JJ'),
#  ('2', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('work', 'NN'),
#  (',', ','),
#  ('Bailey', 'NNP'),
#  ('started', 'VBD'),
#  ('a', 'DT'),
#  ('math', 'NN'),
#  ('tournament', 'NN'),
#  ('in', 'IN'),
#  ('Cincinnati', 'NNP'),
#  ('for', 'IN'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('students', 'NNS'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('4', 'CD'),
#  (']', 'NNP'),
#  ('Exhaust', 'NNP'),
#  ('Nozzle', 'NNP'),
#  ('During', 'IN'),
#  ('her', 'PRP$'),
#  ('tenure', 'NN'),
#  ('at', 'IN'),
#  ('General', 'NNP'),
#  ('Electric', 'NNP'),
#  (',', ','),
#  ('Bailey', 'NNP'),
#  ('patented', 'VBD'),
#  ('an', 'DT'),
#  ('exhaust', 'JJ'),
#  ('nozzle', 'NN'),
#  ('in', 'IN'),
#  ('Evandale', 'NNP'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('initiated', 'VBD'),
#  ('the', 'DT'),
#  ('format', 'NN'),
#  ('that', 'WDT'),
#  ('GE', 'NNP'),
#  ('used', 'VBD'),
#  ('for', 'IN'),
#  ('getting', 'VBG'),
#  ('bids', 'NNS'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('air', 'NN'),
#  ('emission', 'NN'),
#  ('tests', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('4', 'CD'),
#  (']', 'IN'),
#  ('The', 'DT'),
#  ('company', 'NN'),
#  ('had', 'VBD'),
#  ('the', 'DT'),
#  ('7F', 'CD'),
#  ('gas', 'NN'),
#  ('turbine', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first-of-its-kind', 'NN'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('was', 'VBD'),
#  ('working', 'VBG'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('roof', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('building', 'NN'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('familiar', 'JJ'),
#  ('with', 'IN'),
#  ('enough', 'JJ'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('piping', 'NN'),
#  ('to', 'TO'),
#  ('recognize', 'VB'),
#  ('a', 'DT'),
#  ('leak', 'NN'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('gas', 'NN'),
#  ('line', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('gas', 'NN'),
#  ('valve', 'NN'),
#  ('compartment', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('company', 'NN'),
#  ('was', 'VBD'),
#  ('losing', 'VBG'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('gas', 'NN'),
#  ('that', 'WDT'),
#  ('had', 'VBD'),
#  ('already', 'RB'),
#  ('been', 'VBN'),
#  ('counted', 'VBN'),
#  ('as', 'IN'),
#  ('going', 'VBG'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('turbine', 'NN'),
#  ('.', '.'),
#  ('Bailey', 'NNP'),
#  ('noted', 'VBD'),
#  ('the', 'DT'),
#  ('failed', 'JJ'),
#  ('efficiency', 'NN'),
#  ('.', '.'),
#  ('That', 'IN'),
#  ('gas', 'NN'),
#  ('leak', 'NN'),
#  ('was', 'VBD'),
#  ('going', 'VBG'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('incoming', 'NN'),
#  ('gas', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('machine', 'NN'),
#  (',', ','),
#  ('so', 'IN'),
#  ('the', 'DT'),
#  ('carbon', 'NN'),
#  ('monoxide', 'NN'),
#  ('was', 'VBD'),
#  ('destroying', 'VBG'),
#  ('the', 'DT'),
#  ('seal', 'NN'),
#  ('.', '.'),
#  ('All', 'DT'),
#  ('six', 'CD'),
#  ('weeks', 'NNS'),
#  ('of', 'IN'),
#  ('prior', 'JJ'),
#  ('combustion', 'NN'),
#  ('tests', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('employees', 'NNS'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('running', 'VBG'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('machine', 'NN'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('discarded', 'VBN'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('invention', 'NN'),
#  ('straightened', 'VBD'),
#  ('out', 'RP'),
#  ('the', 'DT'),
#  ('problem', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('passed', 'VBD'),
#  ('the', 'DT'),
#  ('tests', 'NNS'),
#  ('after', 'IN'),
#  ('that', 'DT'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('was', 'VBD'),
#  ('important', 'JJ'),
#  ('because', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ("'s", 'POS'),
#  ('gas', 'NN'),
#  ('turbine', 'NN'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('kind', 'NN'),
#  ('and', 'CC'),
#  ('would', 'MD'),
#  ('therefore', 'RB'),
#  ('need', 'VB'),
#  ('to', 'TO'),
#  ('pass', 'VB'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('tests', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('4', 'CD'),
#  (']', 'JJ'),
#  ('Societies', 'NNS'),
#  ('In', 'IN'),
#  ('1964', 'CD'),
#  (',', ','),
#  ('Bailey', 'NNP'),
#  ('attended', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('International', 'NNP'),
#  ('Conference', 'NNP'),
#  ('of', 'IN'),
#  ('Women', 'NNP'),
#  ('Engineers', 'NNPS'),
#  ('and', 'CC'),
#  ('Scientists', 'NNPS'),
#  ('Conference', 'NNP'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('4', 'CD'),
#  (']', 'JJ'),
#  ('Bailey', 'NNP'),
#  ('joined', 'VBD'),
#  ('the', 'DT'),
#  ('Society', 'NNP'),
#  ('of', 'IN'),
#  ('Women', 'NNP'),
#  ('Engineers', 'NNPS'),
#  ('in', 'IN'),
#  ('1951', 'CD'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('officer', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Philadelphia', 'NNP'),
#  ('section', 'NN'),
#  ('and', 'CC'),
#  ('served', 'VBD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('SWE', 'NNP'),
#  ('Executive', 'NNP'),
#  ('Committee', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('1985', 'CD'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('elected', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('SWE', 'NNP'),
#  ('College', 'NNP'),
#  ('of', 'IN'),
#  ('Fellows', 'NNP'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('female', 'JJ'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Engineering', 'NNP'),
#  ('Society', 'NNP'),
#  ('of', 'IN'),
#  ('Cincinnati', 'NNP'),
#  ('and', 'CC'),
#  ('served', 'VBD'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('chair', 'NN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('Guidance', 'NNP'),
#  ('Committee', 'NNP'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('has', 'VBZ'),
#  ('also', 'RB'),
#  ('served', 'VBN'),
#  ('on', 'IN'),
#  ('national', 'JJ'),
#  ('committees', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('National', 'NNP'),
#  ('Society', 'NNP'),
#  ('of', 'IN'),
#  ('Professional', 'NNP'),
#  ('Engineers', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Engineers', 'NNS'),
#  ('Joint', 'NNP'),
#  ('Council', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('American', 'JJ'),
#  ('Society', 'NNP'),
#  ('for', 'IN'),
#  ('Engineering', 'NNP'),
#  ('Education', 'NNP'),
#  ('.', '.')]

# %%
entities = nltk.chunk.ne_chunk(tagged)

# %%
#entities
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~/anaconda3/envs/nlp_environ/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/envs/nlp_environ/lib/python3.6/site-packages/nltk/tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# ~/anaconda3/envs/nlp_environ/lib/python3.6/site-packages/nltk/__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# ~/anaconda3/envs/nlp_environ/lib/python3.6/site-packages/nltk/__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# ~/anaconda3/envs/nlp_environ/lib/python3.6/site-packages/nltk/__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('PERSON', [('Betty', 'NNP')]), Tree('PERSON', [('Lou', 'NNP'), ('Bailey', 'NNP')]), ('(', '('), ('1929', 'CD'), ('–', 'IN'), ('2007', 'CD'), (')', ')'), ('[', 'VBD'), ('1', 'CD'), (']', 'NN'), ('was', 'VBD'), ('a', 'DT'), Tree('ORGANIZATION', [('General', 'NNP'), ('Electric', 'NNP')]), ('Company', 'NNP'), ('mechanical', 'JJ'), ('engineer', 'NN'), ('from', 'IN'), ('the', 'DT'), Tree('GPE', [('United', 'NNP'), ('States', 'NNPS')]), ('.', '.'), ('She', 'PRP'), ('held', 'VBD'), ('a', 'DT'), ('patent', 'NN'), ('for', 'IN'), ('the', 'DT'), ('converging', 'VBG'), ('diverging', 'NN'), ('variable', 'JJ'), ('exhaust', 'JJ'), ('nozzle', 'NN'), ('.', '.'), ('The', 'DT'), ('invention', 'NN'), ('operated', 'VBD'), ('so', 'RB'), ('that', 'IN'), ('one', 'CD'), ('would', 'MD'), ('vary', 'VB'), ('both', 'DT'), ('the', 'DT'), ('throat', 'NN'), ('and', 'CC'), ('the', 'DT'), ('exit', 'NN'), ('diameters', 'NNS'), ('for', 'IN'), ('the', 'DT'), ('hot', 'JJ'), ('gas', 'NN'), ('flows', 'NNS'), ('.', '.'), ('[', '$'), ('2', 'CD'), (']', 'NN'), ('In', 'IN'), ('honor', 'NN'), ('of', 'IN'), ('her', 'PRP$'), ('legacy', 'NN'), (',', ','), ('the', 'DT'), Tree('ORGANIZATION', [('Society', 'NNP')]), ('of', 'IN'), Tree('PERSON', [('Women', 'NNP'), ('Engineers', 'NNP')]), ('named', 'VBD'), ('a', 'DT'), ('scholarship', 'NN'), ('after', 'IN'), ('her', 'PRP$'), ('.', '.'), ('To', 'TO'), ('date', 'NN'), (',', ','), ('that', 'IN'), ('scholarship', 'NN'), ('is', 'VBZ'), ('still', 'RB'), ('being', 'VBG'), ('distributed', 'VBN'), ('to', 'TO'), ('eligible', 'VB'), ('female', 'JJ'), ('graduate', 'NN'), ('students', 'NNS'), ('who', 'WP'), ('pursue', 'VBP'), ('a', 'DT'), ('career', 'NN'), ('in', 'IN'), ('engineering', 'NN'), ('.', '.'), ('[', 'CC'), ('3', 'CD'), (']', 'JJ'), Tree('PERSON', [('Bailey', 'NNP')]), ('was', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('female', 'JJ'), ('member', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Engineering', 'NNP'), ('Society', 'NNP'), ('of', 'IN'), Tree('GPE', [('Cincinnati', 'NNP')]), ('.', '.'), ('She', 'PRP'), ('later', 'RB'), ('served', 'VBD'), ('as', 'IN'), ('the', 'DT'), ('chair', 'NN'), ('of', 'IN'), ('its', 'PRP$'), Tree('ORGANIZATION', [('Guidance', 'NNP'), ('Committee', 'NNP')]), ('.', '.'), Tree('PERSON', [('Bailey', 'NNP')]), ('was', 'VBD'), ('the', 'DT'), ('youngest', 'JJS'), ('of', 'IN'), ('five', 'CD'), ('children', 'NNS'), ('.', '.'), ('She', 'PRP'), ('excelled', 'VBD'), ('in', 'IN'), ('math', 'NN'), ('and', 'CC'), ('science', 'NN'), ('in', 'IN'), ('high', 'JJ'), ('school', 'NN'), ('.', '.'), ('Although', 'IN'), ('her', 'PRP$'), ('father', 'NN'), ('was', 'VBD'), ('a', 'DT'), ('civil', 'JJ'), ('engineer', 'NN'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('her', 'PRP'), ('oldest', 'JJS'), ('sister', 'NN'), Tree('PERSON', [('Helen', 'NNP')]), ('and', 'CC'), ('her', 'PRP$'), ('husband', 'NN'), Tree('PERSON', [('Paul', 'NNP')]), ('who', 'WP'), ('influenced', 'VBD'), Tree('PERSON', [('Bailey', 'NNP')]), ('to', 'TO'), ('choose', 'VB'), ('a', 'DT'), ('career', 'NN'), ('in', 'IN'), ('engineering', 'NN'), ('.', '.'), Tree('PERSON', [('Paul', 'NNP')]), ('sold', 'VBD'), ('welding', 'VBG'), ('machines', 'NNS'), ('and', 'CC'), ('taught', 'VBD'), Tree('PERSON', [('Helen', 'NNP')]), ('to', 'TO'), ('weld', 'VB'), ('.', '.'), Tree('PERSON', [('Helen', 'NNP')]), ('taught', 'VBD'), ('welding', 'VBG'), ('to', 'TO'), ('various', 'JJ'), ('men', 'NNS'), ('and', 'CC'), ('women', 'NNS'), ('during', 'IN'), ('World', 'NNP'), ('War', 'NNP'), ('II', 'NNP'), ('.', '.'), ('Although', 'IN'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), Tree('PERSON', [('Helen', 'NNP')]), ("'s", 'POS'), ('female', 'JJ'), ('welding', 'NN'), ('students', 'NNS'), ('scored', 'VBD'), ('higher', 'JJR'), ('than', 'IN'), ('the', 'DT'), ('male', 'JJ'), ('students', 'NNS'), (',', ','), ('all', 'DT'), ('of', 'IN'), ('the', 'DT'), ('men', 'NNS'), ('were', 'VBD'), ('placed', 'VBN'), ('first', 'RB'), ('before', 'IN'), ('the', 'DT'), ('women', 'NNS'), (',', ','), ('regardless' ...

# %%
#!pip install ghostscript
# Out:
# Collecting ghostscript
#   Downloading https://files.pythonhosted.org/packages/d0/bd/c96072da3a98a498285382ec6ee4b18379c021e4bb6561308e25bc4c04d0/ghostscript-0.6-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in ./anaconda3/envs/nlp_environ/lib/python3.6/site-packages (from ghostscript) (39.2.0)
# mkl-random 1.0.1 requires cython, which is not installed.
# mkl-fft 1.0.0 requires cython, which is not installed.
# Installing collected packages: ghostscript
# Successfully installed ghostscript-0.6

# %%
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}
